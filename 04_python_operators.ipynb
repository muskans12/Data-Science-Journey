# %% [markdown]
# # Python Operators
# ## By Muskan Shaikh
#
# Operators are symbols used to perform operations on variables and values.
#
# Python provides different types of operators such as arithmetic, comparison, logical, and assignment operators.

# %% [markdown]
# ## Arithmetic Operators
#
# Arithmetic operators are used to perform mathematical operations.

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Power:", a ** b)
print("Floor Division:", a // b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Modulus: 1
# Power: 1000
# Floor Division: 3

# %% [markdown]
# ## Comparison Operators
#
# Comparison operators compare two values and return True or False.

# %%
x = 10
y = 5

print(x > y)
print(x < y)
print(x == y)
print(x != y)
print(x >= y)
print(x <= y)
# Out:
# True
# False
# False
# True
# True
# False

# %% [markdown]
# ## Logical Operators
#
# Logical operators combine conditional statements.

# %%
age = 25
salary = 30000

print(age > 18 and salary > 20000)
print(age > 30 or salary > 20000)
print(not(age > 30))
# Out:
# True
# True
# True

# %% [markdown]
# ## Assignment Operators
#
# Assignment operators are used to assign values to variables.

# %%
x = 10

x += 5
print(x)

x *= 2
print(x)
# Out:
# 15
# 30

# %% [markdown]
# ## Practice Example

# %%
a = 15
b = 4

print("Addition:", a + b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Remainder:", a % b)

print(a > b)
print(a == b)
print(a != b)
# Out:
# Addition: 19
# Multiplication: 60
# Division: 3.75
# Remainder: 3
# True
# False
# True

# %% [markdown]
# ## Conclusion
#
# In this notebook we learned about Python operators and how they are used to perform operations and comparisons between variables.
